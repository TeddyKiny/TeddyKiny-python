# %% [markdown]
# Create a program that acts as a simple calculator. It should take two numbers and an operator (+, -, *, /) as input and perform the corresponding arithmetic operation. Add comments to explain each part of the code.

# %%
def calc():
    def calculator():
        first_number = float(input("please enter your first number: "))
        operator = input( "Enter the operator you'd like to use either \n  + \n  - \n  /  \n  *: ")
        Second_number = float(input("please enter your second number: "))

        if operator == '+' :
            result = first_number + Second_number
            print(f"{first_number} + {Second_number} = {result}")
        elif operator == '-' :
            result = first_number - Second_number
            print(f"{first_number} - {Second_number} = {result}")
        elif operator == '*' :
            result = first_number * Second_number
            print(f"{first_number} * {Second_number} = {result}")
        elif operator == '/' :
            if Second_number != 0 :
                result = first_number / Second_number
                print(f"{first_number} / {Second_number} = {result}")
            else:
                print("you can't divide by 0 slow poke!")
        else:
            print("Please enter a valid operator")
    calculator()

calc()
# Out:
# 879.0 / 38.0 = 23.13157894736842

# %% [markdown]
# Write a program that generates and prints a random number between 1 and 100. Use the random library.

# %%
import random
for i in random:
